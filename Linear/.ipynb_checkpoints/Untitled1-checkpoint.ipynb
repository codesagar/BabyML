# %%
import pandas as pd

# %%
data = pd.read_csv("CustomerData.csv")

# %%
data.head(10)
# Out:
#    CustomerID  City  NoOfChildren  MinAgeOfChild  MaxAgeOfChild  Tenure  \
# 0        1001     1             2              3              8     210
# 1        1002     1             2              3              6     442
# 2        1003     1             4              3              5     424
# 3        1004     1             1              6              6     261
# 4        1005     1             3              6              9     422
# 5        1006     1             2              3              4     378
# 6        1007     1             3              8             12     369
# 7        1008     1             2              6              8     404
# 8        1009     1             4              6              9     420
# 9        1010     2             3              5              6     333
#
#    FrquncyOfPurchase  NoOfUnitsPurchased  FrequencyOFPlay  NoOfGamesPlayed  \
# 0                 11                  11             2344              108
# ...

# %%
import statsmodels.formula.api as smf

# %%
" ~ ".join((data.columns.values[7],data.columns.values[-1]))
# Out:
# 'NoOfUnitsPurchased ~ TotalRevenueGenerated'

# %%
formula = " ~ ".join((data.columns.values[-1], data.columns.values[7]))

# %%
print(formula)
# Out:
# TotalRevenueGenerated ~ NoOfUnitsPurchased

# %%
mod = smf.ols(formula=formula, data=data) # Describe model

res = mod.fit()                           # Fit model

print(res.summary())                      # Summarize model
# Out:
#                               OLS Regression Results
# ...
# Dep. Variable:     TotalRevenueGenerated   R-squared:                       0.563
# Model:                               OLS   Adj. R-squared:                  0.563
# Method:                    Least Squares   F-statistic:                     4133.
# Date:                   Thu, 25 Oct 2018   Prob (F-statistic):               0.00
# Time:                           11:09:06   Log-Likelihood:                -17358.
# No. Observations:                   3209   AIC:                         3.472e+04
# Df Residuals:                       3207   BIC:                         3.473e+04
# Df Model:                              1
# Covariance Type:               nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept             42.9829      2.173     19.780      0.000      38.722      47.244
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(data.NoOfUnitsPurchased,data.TotalRevenueGenerated)

# %%
data.corr()
# Out:
#                        CustomerID      City  NoOfChildren  MinAgeOfChild  \
# CustomerID               1.000000 -0.464581      0.053282      -0.016692
# City                    -0.464581  1.000000     -0.065350       0.009865
# NoOfChildren             0.053282 -0.065350      1.000000      -0.179176
# MinAgeOfChild           -0.016692  0.009865     -0.179176       1.000000
# MaxAgeOfChild           -0.003227 -0.032211      0.189002       0.367127
# Tenure                  -0.022263  0.052236      0.085341      -0.055820
# FrquncyOfPurchase        0.064694 -0.099499      0.137630      -0.017568
# NoOfUnitsPurchased       0.046429 -0.066396      0.137040      -0.006191
# FrequencyOFPlay         -0.013333  0.048818      0.165036       0.006690
# NoOfGamesPlayed          0.011404  0.016010      0.213342       0.000104
# NoOfGamesBought          0.030974 -0.034055      0.131398      -0.007748
# TotalRevenueGenerated    0.041756 -0.071110      0.107365       0.024724
#
# ...
